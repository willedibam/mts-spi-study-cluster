# %%
import logging, warnings
import numpy as np, pandas as pd
from pathlib import Path
from scipy.stats import spearmanr, ConstantInputWarning
from tqdm import tqdm
from umap import UMAP
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
import pathlib
import importlib
# importlib.reload(src.X)
# from src.X import x,y,z

from src.utils import iter_dataset_dirs, load_json
from src.plot_style import apply_plot_style

apply_plot_style()
logging.basicConfig(level=logging.INFO, format="%(asctime)s %(levelname)s %(message)s")
warnings.simplefilter("ignore", ConstantInputWarning)

# %% [markdown]
# ##### **`CauchyNoise` vs `GaussianNoise`**

# %%
import pandas as pd
from pathlib import Path

classes = ("VAR(1)-Symmetric", "VAR(1)-Unidirectional")
features_npz = "analysis/features_case_2.npz"
out_dir = Path("analysis/non-overlapping-distributions")
bandwidths = [1.0]

pair_label = "_".join(sorted(classes))  # ensures ks_CML_GaussianNoise == ks_GaussianNoise_CML

# !python find_non_overlapping_distributions.py \
#     --features {features_npz} \
#     --mts-classes {",".join(classes)} \
#     --output-dir {out_dir} \
#     --kde --kde-bandwidth {bandwidths}

for bw in bandwidths:
    csv_path = out_dir / f"kde-{bw}" / f"ks_{pair_label}.csv"
    df = pd.read_csv(csv_path)
    print(f"Top 5 KS for bw={bw}")
    display(df.sort_values("ks_statistic", ascending=False).head(15))
# Out:
# Top 5 KS for bw=1.0
#      feature_index                  SPI-1                           SPI-2  \
# 553            553      tlmi_kraskov_NN-4              tlmi_kernel_W-0.25
# 508            508        mi_kraskov_NN-4   te_symbolic_k-1_kt-1_l-1_lt-1
# 507            507        mi_kraskov_NN-4   gc_gaussian_k-1_kt-1_l-1_lt-1
# 523            523    mi_kraskov_NN-4_DCE   te_symbolic_k-1_kt-1_l-1_lt-1
# 522            522    mi_kraskov_NN-4_DCE   gc_gaussian_k-1_kt-1_l-1_lt-1
# 509            509        mi_kraskov_NN-4  te_symbolic_k-10_kt-1_l-1_lt-1
# 524            524    mi_kraskov_NN-4_DCE  te_symbolic_k-10_kt-1_l-1_lt-1
# 526            526       mi_kernel_W-0.25               tlmi_kraskov_NN-4
# 513            513    mi_kraskov_NN-4_DCE           tlmi_kraskov_NN-4_DCE
# 497            497        mi_kraskov_NN-4               tlmi_kraskov_NN-4
# 561            561      tlmi_kraskov_NN-4   gc_gaussian_k-1_kt-1_l-1_lt-1
# 562            562      tlmi_kraskov_NN-4   te_symbolic_k-1_kt-1_l-1_lt-1
# 573            573  tlmi_kraskov_NN-4_DCE   te_symbolic_k-1_kt-1_l-1_lt-1
# 572            572  tlmi_kraskov_NN-4_DCE   gc_gaussian_k-1_kt-1_l-1_lt-1
# 512            512    mi_kraskov_NN-4_DCE               tlmi_kraskov_NN-4
#
#      ks_statistic  n_VAR(1)-Symmetric  n_VAR(1)-Unidirectional
# 553      0.999608                  96                       96
# 508      0.999573                  96                       96
# 507      0.999573                  96                       96
# 523      0.999418                  96                       96
# 522      0.999418                  96                       96
# 509      0.998755                  96                       96
# 524      0.997734                  96                       96
# 526      0.997203                  96                       96
# 513      0.996631                  96                       96
# 497      0.996570                  96                       96
# 561      0.996252                  96                       96
# 562      0.996252                  96                       96
# 573      0.995489                  96                       96
# 572      0.995489                  96                       96
# 512      0.994000                  96                       96

# %% [markdown]
# ##### **`CauchyNoise` vs `GaussianNoise`**
