# %%
import logging, warnings
import numpy as np, pandas as pd
from pathlib import Path
from scipy.stats import spearmanr, ConstantInputWarning
from tqdm import tqdm
from umap import UMAP
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib.pyplot as plt
import pathlib
import importlib
# importlib.reload(src.X)
# from src.X import x,y,z

from src.utils import iter_dataset_dirs, load_json
from src.plot_style import apply_plot_style

apply_plot_style()
logging.basicConfig(level=logging.INFO, format="%(asctime)s %(levelname)s %(message)s")
warnings.simplefilter("ignore", ConstantInputWarning)

# %% [markdown]
# ##### **`CauchyNoise` vs `GaussianNoise`**

# %%
import pandas as pd
from pathlib import Path

# classes = ("GaussianNoise", "CauchyNoise") #1
classes = ("VAR(1)-Symmetric", "VAR(1)-Unidirectional") #2
# classes = ("Kuramoto-Sync", "Kuramoto-Wave") #3
# classes = ("MackeyGlass", "VAR(1)-Unidirectional") #4
features_npz = "analysis/feature_cache/features_case_2_directed.npz"
out_dir = Path("analysis/non-overlapping-distributions-2/")
bandwidths = [1.0]

pair_label = "_".join(sorted(classes))  # ensur`es ks_CML_GaussianNoise == ks_GaussianNoise_CML

# !python find_non_overlapping_distributions.py \
#     --features {features_npz} \
#     --mts-classes {",".join(classes)} \
#     --output-dir {out_dir} \
#     --kde --kde-bandwidth {bandwidths}

for bw in bandwidths:
    csv_path = out_dir / f"kde-{bw}" / f"ks_{pair_label}.csv"
    df = pd.read_csv(csv_path)
    print(f"Top 5 KS for bw={bw}")
    display(df.sort_values("ks_statistic", ascending=False).head(25))
# Out:
# Top 5 KS for bw=1.0
#       feature_index                      SPI-1  \
# 1306           1306  tlmi_kraskov_NN-4_DCE__ji
# 1304           1304  tlmi_kraskov_NN-4_DCE__ji
# 1347           1347     tlmi_kernel_W-0.25__ji
# 1345           1345     tlmi_kernel_W-0.25__ji
# 1259           1259      tlmi_kraskov_NN-4__ji
# 1261           1261      tlmi_kraskov_NN-4__ji
# 1263           1263      tlmi_kraskov_NN-4__ji
# 1243           1243      tlmi_kraskov_NN-4__ji
# 1308           1308  tlmi_kraskov_NN-4_DCE__ji
# 1192           1192          tlmi_gaussian__ji
# 1210           1210          tlmi_gaussian__ji
# 1212           1212          tlmi_gaussian__ji
# 1302           1302  tlmi_kraskov_NN-4_DCE__ji
# 1190           1190          tlmi_gaussian__ji
# 1110           1110        mi_kraskov_NN-4_DCE
# 1288           1288  tlmi_kraskov_NN-4_DCE__ji
# 1349           1349     tlmi_kernel_W-0.25__ji
# 563             563            ce_kernel_W-0.5
# 1257           1257      tlmi_kraskov_NN-4__ji
# 1343           1343     tlmi_kernel_W-0.25__ji
# 528             528              ce_kozachenko
# 1076           1076            mi_kraskov_NN-4
# 524             524              ce_kozachenko
# 526             526              ce_kozachenko
# 390             390              je_kozachenko
#
#                                    SPI-2  ks_statistic  n_VAR(1)-Symmetric  \
# 1306   te_symbolic_k-1_kt-1_l-1_lt-1__ji      0.994513                  96
# 1304   gc_gaussian_k-1_kt-1_l-1_lt-1__ji      0.994513                  96
# 1347   te_symbolic_k-1_kt-1_l-1_lt-1__ji      0.993652                  96
# 1345   gc_gaussian_k-1_kt-1_l-1_lt-1__ji      0.993652                  96
# 1259   gc_gaussian_k-1_kt-1_l-1_lt-1__ji      0.992798                  96
# 1261   te_symbolic_k-1_kt-1_l-1_lt-1__ji      0.992798                  96
# 1263  te_symbolic_k-10_kt-1_l-1_lt-1__ji      0.986854                  96
# 1243              tlmi_kernel_W-0.25__ji      0.986519                  96
# 1308  te_symbolic_k-10_kt-1_l-1_lt-1__ji      0.986355                  96
# 1192           tlmi_kraskov_NN-4_DCE__ji      0.986078                  96
# 1210   gc_gaussian_k-1_kt-1_l-1_lt-1__ji      0.984719                  96
# 1212   te_symbolic_k-1_kt-1_l-1_lt-1__ji      0.984719                  96
# 1302  gc_gaussian_k-max-10_tau-max-2__ji      0.979306                  96
# 1190               tlmi_kraskov_NN-4__ji      0.978954                  96
# 1110           tlmi_kraskov_NN-4_DCE__ij      0.978694                  96
# 1288              tlmi_kernel_W-0.25__ji      0.977159                  96
# 1349  te_symbolic_k-10_kt-1_l-1_lt-1__ji      0.975462                  96
# 563                      mi_kraskov_NN-4      0.975293                  96
# 1257  gc_gaussian_k-max-10_tau-max-2__ji      0.974471                  96
# 1343  gc_gaussian_k-max-10_tau-max-2__ji      0.973415                  96
# 528               tlmi_kernel_W-0.25__ij      0.971094                  96
# 1076                    mi_kernel_W-0.25      0.970798                  96
# 524                tlmi_kraskov_NN-4__ij      0.968717                  96
# 526            tlmi_kraskov_NN-4_DCE__ij      0.968067                  96
# 390               tlmi_kernel_W-0.25__ij      0.967929                  96
#
#       n_VAR(1)-Unidirectional
# 1306                       96
# 1304                       96
# 1347                       96
# 1345                       96
# 1259                       96
# 1261                       96
# 1263                       96
# 1243                       96
# 1308                       96
# 1192                       96
# 1210                       96
# 1212                       96
# 1302                       96
# 1190                       96
# 1110                       96
# 1288                       96
# 1349                       96
# 563                        96
# 1257                       96
# 1343                       96
# 528                        96
# 1076                       96
# 524                        96
# 526                        96
# 390                        96

# %% [markdown]
# ##### **`CauchyNoise` vs `GaussianNoise`**
